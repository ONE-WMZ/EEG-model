# %% [markdown]
# ### Channel_attention
# ####   输入：(8, 22, 32)
# ####   输出：（8，1，32）
#
# ---

# %%
from Model_block import Channel_attention

# %%
import torch
model = Channel_attention(22)
print(model)
inputs = torch.rand(8, 22, 32)
out = model(inputs)
print(out)
# Out:
# Channel_attention(
#   (avg_pool): AdaptiveAvgPool1d(output_size=1)
#   (max_pool): AdaptiveMaxPool1d(output_size=1)
#   (fc): Sequential(
#     (0): Linear(in_features=22, out_features=11, bias=False)
#     (1): ReLU()
#     (2): Linear(in_features=11, out_features=22, bias=False)
#   )
#   (sigmoid): Sigmoid()
# )
# tensor([[[5.7826, 5.3611, 4.8376, 5.2344, 5.4170, 6.0515, 4.6058, 5.6056,
#           4.6096, 4.1241, 4.7515, 5.8133, 6.3023, 6.3138, 6.7163, 4.9970,
#           6.1618, 4.5843, 5.1136, 6.5415, 5.6061, 5.8885, 5.8718, 6.5616,
#           6.9784, 5.5255, 6.0399, 5.5083, 4.8201, 4.9460, 4.3174, 3.0208]],
#
#         [[5.5133, 5.5837, 4.7511, 5.3525, 4.8375, 5.9927, 5.7270, 6.8260,
#           5.1695, 5.7973, 5.8254, 4.9674, 5.3308, 5.1754, 6.1686, 4.8368,
#           5.5412, 6.3241, 5.4844, 5.7459, 5.3688, 4.5492, 6.7661, 5.6375,
#           6.5704, 5.4583, 4.7998, 5.5847, 4.7438, 5.7577, 5.9350, 4.5490]],
#
# ...

# %%
print(out.shape)
# Out:
# torch.Size([8, 1, 32])
