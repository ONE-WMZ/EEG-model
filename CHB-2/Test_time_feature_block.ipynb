# %% [markdown]
# ## Time_feature_block：
# ### 输入：（8，22，64）
# ### 输出：（8，22，32）
#
# ---

# %%
from Model_block import Time_feature_block
import torch

# %%
model = Time_feature_block()
x = torch.rand(8,22,64)

# %%
print(model)
# Out:
# Time_feature_block(
#   (conv1): Sequential(
#     (0): Conv1d(22, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (conv2): Sequential(
#     (0): Conv1d(64, 32, kernel_size=(3,), stride=(2,), padding=(1,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (final_conv): Conv1d(32, 22, kernel_size=(1,), stride=(1,))
# )

# %%
out = model(x)

# %%
print(out)
print(out.shape)
# Out:
# tensor([[[-4.4877e-02,  6.7902e-01, -3.6080e-01,  ...,  6.9675e-02,
#            3.1720e-01, -3.1915e-01],
#          [ 1.5529e-01,  2.6670e-01,  2.3709e-01,  ...,  1.2244e-01,
#           -3.9811e-01,  6.1906e-01],
#          [-1.7351e-02, -2.2307e-01, -4.3468e-01,  ..., -6.0720e-01,
#           -1.1221e-01,  4.5315e-02],
#          ...,
#          [ 2.8836e-01, -1.1386e+00, -3.5181e-01,  ..., -3.8767e-01,
#           -5.5271e-01, -1.9725e-01],
#          [ 1.1086e-01,  3.7687e-01,  9.3949e-02,  ..., -3.1011e-04,
#           -4.0758e-01,  1.6005e-01],
#          [-4.0250e-01,  2.4233e-01, -1.8350e-01,  ...,  3.1205e-01,
#           -1.5366e-01, -2.6470e-01]],
#
#         [[ 2.0149e-01, -4.6361e-01,  3.2635e-01,  ..., -6.9470e-01,
#            3.6675e-01,  5.4692e-02],
#          [ 2.3315e-01,  7.4183e-02, -5.5378e-02,  ...,  2.0427e-01,
#           -8.4258e-02,  7.7835e-01],
#          [-2.4699e-02,  1.1663e-02, -3.7141e-01,  ..., -5.7411e-01,
#            3.0363e-02, -2.1364e-01],
# ...

# %% [markdown]
# ### 输入：（8，22，64）
# ### 输出：（8，22，32）
