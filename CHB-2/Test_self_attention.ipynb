# %% [markdown]
# # Self_attention_block
# ####  输入：（8，8，32）
# ####  输出：（8，1，64）
#
# ---

# %%
from Model_block import Self_attention_block
import torch

# %%
model = Self_attention_block(32, 8)

x = torch.rand(8,8,32)

# %%
print(x)
# Out:
# tensor([[[0.1699, 0.6794, 0.0816,  ..., 0.8733, 0.7225, 0.5290],
#          [0.3680, 0.5685, 0.2065,  ..., 0.0182, 0.3689, 0.5879],
#          [0.0053, 0.2601, 0.1929,  ..., 0.0799, 0.5488, 0.8563],
#          ...,
#          [0.0687, 0.5541, 0.1642,  ..., 0.3317, 0.3914, 0.4878],
#          [0.3063, 0.0406, 0.8397,  ..., 0.7430, 0.3390, 0.7411],
#          [0.1976, 0.1529, 0.2532,  ..., 0.5051, 0.3330, 0.0963]],
#
#         [[0.6059, 0.3295, 0.9002,  ..., 0.5947, 0.8169, 0.9407],
#          [0.7833, 0.1313, 0.9705,  ..., 0.5158, 0.8233, 0.5885],
#          [0.2741, 0.4397, 0.8091,  ..., 0.8828, 0.5689, 0.3321],
#          ...,
#          [0.6670, 0.5338, 0.3329,  ..., 0.4654, 0.9045, 0.6520],
#          [0.7375, 0.4458, 0.8952,  ..., 0.7166, 0.1735, 0.8019],
#          [0.5720, 0.9666, 0.8783,  ..., 0.3772, 0.7579, 0.9111]],
#
#         [[0.8406, 0.2472, 0.1368,  ..., 0.6455, 0.9827, 0.1975],
#          [0.3055, 0.6983, 0.4593,  ..., 0.7900, 0.7919, 0.8420],
# ...

# %%
out = model(x)
print(out)
print(out.shape)
# Out:
# tensor([[[ 0.1551, -0.4953, -0.2044, -0.3650,  0.0068, -0.1280, -0.2257,
#           -0.0517]],
#
#         [[ 0.1282, -0.5186, -0.1837, -0.3985, -0.0575, -0.0950, -0.2810,
#           -0.0168]],
#
#         [[ 0.0527, -0.4287, -0.2427, -0.3100, -0.0529,  0.0172, -0.2572,
#           -0.0618]],
#
#         [[ 0.1184, -0.5610, -0.1335, -0.4244, -0.0438, -0.0822, -0.2590,
#           -0.0500]],
#
#         [[ 0.0758, -0.4967, -0.2046, -0.3344, -0.0627, -0.0646, -0.2817,
#           -0.0461]],
#
#         [[ 0.0869, -0.5129, -0.1669, -0.3742, -0.0530, -0.0655, -0.2425,
#           -0.0372]],
#
#         [[ 0.0834, -0.5162, -0.1790, -0.3677, -0.1061, -0.0624, -0.2916,
#            0.0091]],
#
#         [[ 0.0940, -0.5051, -0.1767, -0.3813, -0.0376, -0.1283, -0.2528,
#           -0.0394]]], grad_fn=<ViewBackward0>)
# torch.Size([8, 1, 8])
