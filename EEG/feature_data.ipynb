# %% [markdown]
# # 特征数据

# %% [markdown]
# ---
# ### 导入相关库文件

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio

# %% [markdown]
# ---
# ### 读取第一个受试者的第一次实验数据

# %%
feature_data = sio.loadmat('F:/SEED_IV/eeg_feature_smooth/1/1_20160518.mat')
print(type(feature_data))                                        # 字典格式文件
print(feature_data.keys())                                       # 查看关键字
# Out:
# <class 'dict'>
# ...

# %% [markdown]
# ---
# ### 看电极的数据

# %%
de_LDS1 = feature_data['de_LDS1']                           # DE特征，线性动态系统
print(type(de_LDS1))
print(de_LDS1.shape)
print(de_LDS1[0])                                           # 第一个电极
# 2min/4s = 30simple   每个在两分钟左右
# Out:
# <class 'numpy.ndarray'>
# (62, 42, 5)
# [[27.79550063 25.00743779 22.85596069 21.52398377 19.97860112]
#  [27.79681682 25.00842641 22.85581714 21.52387267 19.97898348]
#  [27.79766669 25.00932374 22.85594488 21.52342945 19.97865108]
#  [27.79741131 25.00938876 22.85548246 21.52298262 19.97860887]
#  [27.7955276  25.00809552 22.85422137 21.52259402 19.97851365]
#  [27.79228454 25.00679201 22.85280125 21.52040559 19.97575514]
#  [27.78719204 25.00361097 22.85055611 21.51765098 19.97208013]
#  [27.78052041 24.99897054 22.84856723 21.51560217 19.96755678]
#  [27.77572625 24.99551743 22.84741247 21.51394593 19.96254875]
#  [27.76967176 24.99163873 22.84625254 21.51151118 19.95685309]
#  [27.76151705 24.98657998 22.84431514 21.50846551 19.95131911]
#  [27.75400675 24.98181572 22.84207969 21.50574078 19.94579315]
#  [27.74830225 24.97802722 22.83963863 21.50252608 19.94041455]
#  [27.74257412 24.9739836  22.83641538 21.49947064 19.93483872]
# ...

# %%
de_LDS1_1 = de_LDS1[0,:,0]                               # 第1个波频
de_LDS1_2 = de_LDS1[0,:,1]                               # 第2个波频
de_LDS1_3 = de_LDS1[0,:,2]                               # 第3个波频
de_LDS1_4 = de_LDS1[0,:,3]                               # 第4个波频
de_LDS1_5 = de_LDS1[0,:,4]                               # 第5个波频

# %%
plt.subplot(2, 3, 1)
plt.plot(de_LDS1_1)
plt.subplot(2, 3, 2)
plt.plot(de_LDS1_2)
plt.subplot(2, 3, 3)
plt.plot(de_LDS1_3)
plt.subplot(2, 3, 4)
plt.plot(de_LDS1_4)
plt.subplot(2, 3, 5)
plt.plot(de_LDS1_5)
plt.show()
