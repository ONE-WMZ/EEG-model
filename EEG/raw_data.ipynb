# %% [markdown]
# # 原始数据

# %% [markdown]
# ---
# ### 导入相关库文件

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio

# %% [markdown]
# ---
# ### 提取第一次实验的第一个受试者的原始脑电数据

# %%
raw_data = sio.loadmat('F:/SEED_IV/eeg_raw_data/1/1_20160518.mat')    # 第一个受试者
p1 = raw_data['cz_eeg1']                                                           # 第一个片段（电影）
p11 = p1[0]                                                                        # 第1个电极
p12 = p1[1]                                                                        # 第2个电极

# %% [markdown]
# ---
# ### 画图

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(p11[:], label='1')
ax2.plot(p12[:], label='2')
plt.show()

# %%
print(p1.shape)
print(p11.shape)
# Out:
# (62, 33601)
# (33601,)
