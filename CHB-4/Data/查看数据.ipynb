# %%
import numpy as np

# %%
np_path = 'train/label_1/chb12.npy'
data = np.load(np_path)

# %%
import matplotlib.pyplot as plt

# 假设你想绘制第一个通道的数据
plt.figure(figsize=(14, 4))
plt.plot(data[3, :])  # 绘制第0个通道的所有时间点
plt.title('EEG Data for Channel 0')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude (μV)')
plt.show()

# %%
print(data.shape)
print(data.shape[1]/200,'秒')
print(data.shape[1]/200/60,'分')
# Out:
# (6, 197800)
# 989.0 秒
# 16.483333333333334 分
