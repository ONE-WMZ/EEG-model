# %%
from pre_train import loader

# %%
for x in loader:
        print(x.shape)
print(len(loader))
# Out:
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# torch.Size([32, 22, 512])
# ...
